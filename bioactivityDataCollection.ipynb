# %% [markdown]
# ## **Data Collection & Preprocessing from Bioactivity database "ChEMBYL"**

# %% [markdown]
# # ChEMBL Database
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/)

# %%
! pip install chembl_webresource_client

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('coronavirus')      # You can modify the search query according to your need.
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  ...   tax_id
# 0                                                 []  ...    11119
# 1                                                 []  ...   227859
# 2                                                 []  ...    12663
# 3                                                 []  ...    11137
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...  ...   227859
# 5                                                 []  ...  1335626
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...  ...   227859
# 7                                                 []  ...  2697049
#
# [8 rows x 9 columns]

# %% [markdown]
# **Retrieving bioactivity data for SARS coronavirus 3C-like proteinase which is at index 4**

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type = "IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id  ... upper_value value
# 0             None      1480935  ...        None   7.2
# 1             None      1480936  ...        None   9.4
# 2             None      1481061  ...        None  13.5
#
# [3 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Standard value represents potency of the drug, lower the number better the drug!

# %%
df.to_csv('01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# Taking a look at the csv file we created.

# %%
! head bioactivity_data.csv
# Out:
# head: cannot open 'bioactivity_data.csv' for reading: No such file or directory

# %% [markdown]
# **Handling missing data:**
# Dropping the row/compound which has missing value for standard_value and canonical_smiles.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 128             None     12041507  ...        None   10.6
# 129             None     12041508  ...        None   10.1
# 130             None     12041509  ...        None   11.5
# 131             None     12041510  ...        None   10.7
# 132             None     12041511  ...        None   78.9
#
# [133 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 86

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 109             None     12040781  ...        None   21.1
# 110             None     12040782  ...        None  226.7
# 111             None     12040783  ...        None   38.7
# 112             None     12040784  ...        None   14.4
# 113             None     12040785  ...        None   21.1
#
# [86 rows x 45 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 109      CHEMBL2146517  ...        21100.0
# 110       CHEMBL187460  ...       226700.0
# 111       CHEMBL363535  ...        38700.0
# 112       CHEMBL227075  ...        14400.0
# 113        CHEMBL45830  ...        21100.0
#
# [86 rows x 3 columns]

# %%
df3.to_csv('02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# # **Labelling Compounds**:
# **Active**: Value < 1000 nM.
# **Intermediate**: 1000 nM < Value < 10000 nM.
# **Inactive**: Value > 10000 nM.
# nM = Nanomolar

# %%
df4 = pd.read_csv('02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id  ...         class
# 0        CHEMBL187579  ...  intermediate
# 1        CHEMBL188487  ...  intermediate
# 2        CHEMBL185698  ...      inactive
# 3        CHEMBL426082  ...      inactive
# 4        CHEMBL187717  ...  intermediate
# ..                ...  ...           ...
# 81      CHEMBL2146517  ...      inactive
# 82       CHEMBL187460  ...      inactive
# 83       CHEMBL363535  ...      inactive
# 84       CHEMBL227075  ...      inactive
# 85        CHEMBL45830  ...      inactive
#
# [86 rows x 4 columns]

# %% [markdown]
# Save Dataframe to CSV

# %%
df5.to_csv('03_bioactivity_data_curated.csv', index=False)
